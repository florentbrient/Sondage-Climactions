# %%
#from mpl_toolkits.basemap import Basemap
from matplotlib import cm
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('Reponse_FR.csv')

# %%
df.shape
# Out:
# (79, 21)

# %%
print('Nombre de réponses : ',df.shape[0])
# Out:
# Nombre de réponses :  79

# %%
df.head()
# Out:
#                     Horodateur  \
# 0  2021/03/25 3:46:39 PM UTC+2
# 1  2021/03/25 3:48:09 PM UTC+2
# 2  2021/03/25 3:48:42 PM UTC+2
# 3  2021/03/25 3:49:18 PM UTC+2
# 4  2021/03/25 3:49:24 PM UTC+2
#
#                          Quel est votre profession ?  \
# 0  Recherche et Enseignement (y compris doctorant...
# 1  Support à la recherche (Ingénieur / Technicien...
# 2  Support à la recherche (Ingénieur / Technicien...
# 3  Recherche et Enseignement (y compris doctorant...
# 4  Recherche et Enseignement (y compris doctorant...
#
#   Votre poste est-il permanent ?  \
# 0                            Non
# 1                            Oui
# 2                            Non
# 3                            Oui
# 4                            Non
#
#   Sur quel site travaillez-vous majoritairement ?  \
# 0                             Ecole Polytechnique
# 1                             Ecole Polytechnique
# 2                             Ecole Polytechnique
# ...

# %%
df['Quel est votre profession ?'].value_counts(normalize=True)
# Out:
# Recherche et Enseignement (y compris doctorant et post-doc)       0.670886
# Support à la recherche (Ingénieur / Technicien /Administratif)    0.329114
# Name: Quel est votre profession ?, dtype: float64

# %%
#matplotlib inline
#fig, axs = plt.figure(figsize=(25,7))
#df['Quel est votre profession ?'].value_counts().plot(kind="bar", figsize=(15,7), color="#61d199")
fig, axs = plt.figure(figsize=(25,7))
plt.figure()
plt.plot(df['Votre poste est-il permanent ?'].value_counts(),kind="bar", color="#61d199")
# Out:
# UsageError: Line magic function `%fig,` not found.

# %%
said_yes = df[df['Votre poste est-il permanent ?'] == 'Oui']
said_no = df[df['Votre poste est-il permanent ?'] == 'Non']
said_no.shape
# Out:
# (30, 21)

# %%
# Out:
# ['Horodateur',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...
